# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# Given the data on the number of hours students studied and their exam scores. Create a scatter plot to see if there is a linear relationship between study time and exam performance: Study Time (in hours): [2, 3, 5, 7, 8, 10, 12, 15, 18, 20] Exam Scores (out of 100): [50, 55, 65, 70, 75, 80, 85, 88, 90, 95]b

# %%
data = {"study_time":[2, 3, 5, 7, 8, 10, 12, 15, 18, 20],
        "exam_score":[50, 55, 65, 70, 75, 80, 85, 88, 90, 95]
       }
df = pd.DataFrame(data)
plt.scatter()
plt.x_label("study_time")
plt.y_label("exam_scores")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 data = {"study_time":[2, 3, 5, 7, 8, 10, 12, 15, 18, 20],
#       2         "exam_score":[50, 55, 65, 70, 75, 80, 85, 88, 90, 95]
#       3        }
#       4 df = pd.DataFrame(data)
# ----> 5 plt.scatter()
#       6 plt.x_label("study_time")
#       7 plt.y_label("exam_scores")
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'
